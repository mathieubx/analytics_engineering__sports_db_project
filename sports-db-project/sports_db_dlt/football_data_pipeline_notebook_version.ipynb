# %%
# A pipeline coded the good old way

# Let's build a function for the football data source. 
# Its arguments will be: 
#   endpoint, 
#   params (I'll start with data from the 2023/2024 season),   
#   column names (list)
# That way we can call the function without copy pasting the code again and again for each endpoint

import requests
import pandas as pd
import duckdb
import toml
import datetime
from datetime import datetime as dt 
import time

# /?dateFrom=2022-01-01
# /?dateTo=2022-01-10

def extract_load_football_data(
        endpoint = None,
        column_names = None,
        **params # Note: Arbitrary keyword arguments are dictionaries
):
    
    # Step 0: import API credentials
    secrets=toml.load("C:/Users/mbmbm/matbx-data/sports-db-project/sports_db_dlt/.dlt/secrets.toml")
    request_header=secrets['source']['football_data']['request_header']
    api_key=secrets['source']['football_data']['api_key']

    # Step 1: Define request URL
    # If there are no parameters passed to the function (meaning: params is an empty dictionary), take the whole endpoint
    if params == {}: 
        url = f'https://api.football-data.org/v4/{endpoint}'
    else:
        url = f'https://api.football-data.org/v4/{endpoint}/?dateFrom={params['start_date']}&dateTo={params['end_date']}' # Note: we access each params' key's value as in any dictionary

    # Step 2: Make the GET request to the API, using a header to authenticate through API key
    response = requests.get(url, headers={request_header:api_key})

    # Step 3: Convert the JSON returned to a pandas DataFrame
    endpoint_df = pd.DataFrame(
        data=response.json()[f'{endpoint}'],
        columns = column_names
    )

    # DuckDB documentation to load data from pandas: https://duckdb.org/docs/stable/guides/python/import_pandas.html
    # Here, the "with" structure is a context manager that enables to close the connection (created on the just above line) automatically
    try:
        with duckdb.connect("C:/Users/mbmbm/matbx-data/sports-db-project/duckdb-databases/sports_db-raw.duckdb") as con:
            con.sql(f"CREATE OR REPLACE TABLE {endpoint} AS SELECT * FROM endpoint_df")
        message="Successfully pushed dataframe to DuckDB"
    except:
        message="Error, couldn't load data into DuckDB"

    return(message)

# %%
# Calling pipelines

# Competitions
extract_load_football_data(
    endpoint='competitions', 
    column_names=[
        'id', 
        'area', 
        'name', 
        'code', 
        'type', 
        'currentSeason', 
        'lastUpdated'
    ]
)

# Areas
extract_load_football_data(
    endpoint='areas', 
    column_names=[ 
        "id",
        "name",
        "countryCode",
        "flag",
        "parentAreaId",
        "parentArea"
    ]
)

# Teams
extract_load_football_data(
    endpoint='teams', 
    column_names=[ 
        "id",
        "area",
        "name",
        "shortName",
        "tla",
        "address",
        "website",
        "founded",
        "clubColors",
        "venue",
        "runningCompetitions",
        "coach",
        "marketValue",
        "squad",
        "staff",
        "lastUpdated"
    ]
)
# Out:
# 'Successfully pushed dataframe to DuckDB'

# %%
time.sleep(300)
# Step 0: import API credentials
secrets=toml.load("C:/Users/mbmbm/matbx-data/sports-db-project/sports_db_dlt/.dlt/secrets.toml")
request_header=secrets['source']['football_data']['request_header']
api_key=secrets['source']['football_data']['api_key']

# Seems like data is available from 2024-06-01
# Also, specified period cannot exceed 10 days
# What to do in this section: Build 10-days periods and extract matches for each and every one of them

# Step 1: Build 10-days periods 

# Intialization
start_date = dt.strptime("2024-08-01", "%Y-%m-%d") # From around the start of the major leagues' 2024/25 season
end_date = dt.now()
date_iterator = start_date
periods = []

while date_iterator <= end_date:
    start_date = date_iterator
    date_iterator = date_iterator + datetime.timedelta(days=10)
    periods.append({"start_date":start_date, "end_date":date_iterator})

ten_days_periods = pd.DataFrame(periods)

# Step 2: Pull data from API for each 10-days period to get all matches for the current season
# It is clearly specified in the documentation that the max number of requests per minute is 10. We set a 60 second timer after each 10 requests.

i = 0 # Setting a counter (i) to rest 60 seconds after 10 requests
matches_list = [] # Setting an empty list to store API calls results

for index, period in ten_days_periods.iterrows():
    i = i + 1
    period_start_date = dt.strftime(period['start_date'], "%Y-%m-%d") # Format for inserting the date in the request's url
    period_end_date = dt.strftime(period['end_date'] - datetime.timedelta(days = 1), "%Y-%m-%d") # Substracting 1 day to avoid duplicating last day of the period
    
    # Making the actual requests
    url = f"https://api.football-data.org/v4/matches/?dateFrom={period_start_date}&dateTo={period_end_date}"
    print(url)
    print(requests.get(url, headers={request_header:api_key}).json())
    try:
        response = requests.get(url, headers={request_header:api_key}).json()['matches'] # This is a list
    except:
        print("Failed at api request")
    matches_list.append(response)

    if i%5==0: time.sleep(60) # Stop the program for 60 second each 5 requests. Why 5? Because it feels like the "10 requests per minute" are too much for the API
# Out:
# https://api.football-data.org/v4/matches/?dateFrom=2024-08-01&dateTo=2024-08-10
# {'filters': {'dateFrom': '2024-08-01', 'dateTo': '2024-08-10', 'permission': 'TIER_ONE'}, 'resultSet': {'count': 14, 'competitions': 'BSA,DED,ELC,PPL', 'first': '2024-08-03', 'last': '2024-08-09', 'played': 14}, 'matches': [{'area': {'id': 2032, 'name': 'Brazil', 'code': 'BRA', 'flag': 'https://crests.football-data.org/764.svg'}, 'competition': {'id': 2013, 'name': 'Campeonato Brasileiro Série A', 'code': 'BSA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/bsa.png'}, 'season': {'id': 2257, 'startDate': '2024-04-13', 'endDate': '2024-12-08', 'currentMatchday': 38, 'winner': None}, 'id': 493962, 'utcDate': '2024-08-03T19:00:00Z', 'status': 'FINISHED', 'matchday': 21, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2024-12-22T20:20:40Z', 'homeTeam': {'id': 1782, 'name': 'EC Vitória', 'shortName': 'Vitória', 'tla': 'VIT', 'crest': 'https://crests.football-data.org/1782.png'}, 'awayTeam': {'id': 4289, 'name': 'Cuiabá EC', 'shortName': 'Cuiabá EC', 'tla': 'CUI', 'crest': 'https://crests.football-data.org/4289_large.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 0}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2032, 'name': 'Brazil', 'code': 'BRA', 'flag': 'https://crests.football-data.org/764.svg'}, 'competition': {'id': 2013, 'name': 'Campeonato Brasileiro Série A', 'code': 'BSA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/bsa.png'}, 'season': {'id': 2257, 'startDate': '2024-04-13', 'endDate': '2024-12-08', 'currentMatchday': 38, 'winner': None}, 'id': 493961, 'utcDate': '2024-08-03T22:00:00Z', 'status': 'FINISHED', 'matchday': 21, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2024-12-22T20:20:40Z', 'homeTeam': {'id': 1780, 'name': 'CR Vasco da Gama', 'shortName': 'Vasco da Gama', 'tla': 'VAS', 'crest': 'https://crests.football-data.org/1780.png'}, 'awayTeam': {'id': 4286, 'name': 'RB Bragantino', 'shortName': 'Bragantino', 'tla': 'RBB', 'crest': 'https://crests.football-data.org/4286.png'}, 'score': {'winner': 'DRAW', 'duration': 'REGULAR', 'fullTime': {'home': 2, 'away': 2}, 'halfTime': {'home': 0, 'away': 1}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2032, 'name': 'Brazil', 'code': 'BRA', 'flag': 'https://crests.football-data.org/764.svg'}, 'competition': {'id': 2013, 'name': 'Campeonato Brasileiro Série A', 'code': 'BSA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/bsa.png'}, 'season': {'id': 2257, 'startDate': '2024-04-13', 'endDate': '2024-12-08', 'currentMatchday': 38, 'winner': None}, 'id': 493954, 'utcDate': '2024-08-03T23:00:00Z', 'status': 'FINISHED', 'matchday': 21, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2024-12-22T20:20:40Z', 'homeTeam': {'id': 3988, 'name': 'AC Goianiense', 'shortName': 'AC Goianiense', 'tla': 'ACG', 'crest': 'https://crests.football-data.org/3988.png'}, 'awayTeam': {'id': 1770, 'name': 'Botafogo FR', 'shortName': 'Botafogo', 'tla': 'BOT', 'crest': 'https://crests.football-data.org/1770.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 4}, 'halfTime': {'home': 1, 'away': 1}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2032, 'name': 'Brazil', 'code': 'BRA', 'flag': 'https://crests.football-data.org/764.svg'}, 'competition': {'id': 2013, 'name': 'Campeonato Brasileiro Série A', 'code': 'BSA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/bsa.png'}, 'season': {'id': 2257, 'startDate': '2024-04-13', 'endDate': '2024-12-08', 'currentMatchday': 38, 'winner': None}, 'id': 493956, 'utcDate': '2024-08-03T23:00:00Z', 'status': 'FINISHED', 'matchday': 21, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2024-12-22T20:20:40Z', 'homeTeam': {'id': 4243, 'name': 'Criciúma EC', 'shor ...
# https://api.football-data.org/v4/matches/?dateFrom=2024-08-11&dateTo=2024-08-20
# {'filters': {'dateFrom': '2024-08-11', 'dateTo': '2024-08-20', 'permission': 'TIER_ONE'}, 'resultSet': {'count': 107, 'competitions': 'BSA,DED,PPL,ELC,CLI,PD,FL1,PL,SA', 'first': '2024-08-11', 'last': '2024-08-19', 'played': 107}, 'matches': [{'area': {'id': 2032, 'name': 'Brazil', 'code': 'BRA', 'flag': 'https://crests.football-data.org/764.svg'}, 'competition': {'id': 2013, 'name': 'Campeonato Brasileiro Série A', 'code': 'BSA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/bsa.png'}, 'season': {'id': 2257, 'startDate': '2024-04-13', 'endDate': '2024-12-08', 'currentMatchday': 38, 'winner': None}, 'id': 493965, 'utcDate': '2024-08-11T00:30:00Z', 'status': 'FINISHED', 'matchday': 22, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2024-12-22T20:20:40Z', 'homeTeam': {'id': 1771, 'name': 'Cruzeiro EC', 'shortName': 'Cruzeiro', 'tla': 'CRU', 'crest': 'https://crests.football-data.org/1771.png'}, 'awayTeam': {'id': 1766, 'name': 'CA Mineiro', 'shortName': 'Mineiro', 'tla': 'CAM', 'crest': 'https://crests.football-data.org/1766.png'}, 'score': {'winner': 'DRAW', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 0}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2032, 'name': 'Brazil', 'code': 'BRA', 'flag': 'https://crests.football-data.org/764.svg'}, 'competition': {'id': 2013, 'name': 'Campeonato Brasileiro Série A', 'code': 'BSA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/bsa.png'}, 'season': {'id': 2257, 'startDate': '2024-04-13', 'endDate': '2024-12-08', 'currentMatchday': 38, 'winner': None}, 'id': 493964, 'utcDate': '2024-08-11T00:30:00Z', 'status': 'FINISHED', 'matchday': 22, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2024-12-22T20:20:40Z', 'homeTeam': {'id': 1779, 'name': 'SC Corinthians Paulista', 'shortName': 'Corinthians', 'tla': 'COR', 'crest': 'https://crests.football-data.org/1779.png'}, 'awayTeam': {'id': 4286, 'name': 'RB Bragantino', 'shortName': 'Bragantino', 'tla': 'RBB', 'crest': 'https://crests.football-data.org/4286.png'}, 'score': {'winner': 'DRAW', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 1}, 'halfTime': {'home': 1, 'away': 1}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 60899, 'name': 'Felipe Fernandes de Lima', 'type': 'REFEREE', 'nationality': 'Brazil'}]}, {'area': {'id': 2032, 'name': 'Brazil', 'code': 'BRA', 'flag': 'https://crests.football-data.org/764.svg'}, 'competition': {'id': 2013, 'name': 'Campeonato Brasileiro Série A', 'code': 'BSA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/bsa.png'}, 'season': {'id': 2257, 'startDate': '2024-04-13', 'endDate': '2024-12-08', 'currentMatchday': 38, 'winner': None}, 'id': 493972, 'utcDate': '2024-08-11T00:30:00Z', 'status': 'FINISHED', 'matchday': 22, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2024-12-22T20:20:40Z', 'homeTeam': {'id': 1780, 'name': 'CR Vasco da Gama', 'shortName': 'Vasco da Gama', 'tla': 'VAS', 'crest': 'https://crests.football-data.org/1780.png'}, 'awayTeam': {'id': 1765, 'name': 'Fluminense FC', 'shortName': 'Fluminense', 'tla': 'FLU', 'crest': 'https://crests.football-data.org/1765.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 2, 'away': 0}, 'halfTime': {'home': 2, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 11161, 'name': 'Anderson Daronco', 'type': 'REFEREE', 'nationality': 'Brazil'}]}, {'area': {'id': 2163, 'name': 'Netherlands', 'code': 'NLD', 'flag': 'https://crests.football-data.org/8601.svg'}, 'competition': {'id': 2003, 'name': 'Eredivisie', 'code': 'DED', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/ED.png'}, 'season': {'id': 2293, 'startDate': '2024-08-09', 'endDate': '2025-05-18', 'currentMatchday': 26, 'winner': None}, 'id': 498998, 'utcDate': '2024-08-11 ...
# https://api.football-data.org/v4/matches/?dateFrom=2024-08-21&dateTo=2024-08-30
# {'filters': {'dateFrom': '2024-08-21', 'dateTo': '2024-08-30', 'permission': 'TIER_ONE'}, 'resultSet': {'count': 104, 'competitions': 'CLI,PD,BL1,FL1,ELC,PPL,PL,SA,DED,BSA', 'first': '2024-08-21', 'last': '2024-08-29', 'played': 104}, 'matches': [{'area': {'id': 2220, 'name': 'South America', 'code': 'SAM', 'flag': 'https://crests.football-data.org/CLI.svg'}, 'competition': {'id': 2152, 'name': 'Copa Libertadores', 'code': 'CLI', 'type': 'CUP', 'emblem': 'https://crests.football-data.org/CLI.svg'}, 'season': {'id': 1644, 'startDate': '2024-02-07', 'endDate': '2024-10-31', 'currentMatchday': 6, 'winner': None}, 'id': 517542, 'utcDate': '2024-08-21T00:30:00Z', 'status': 'FINISHED', 'matchday': 2, 'stage': 'LAST_16', 'group': None, 'lastUpdated': '2024-11-14T20:21:09Z', 'homeTeam': {'id': 1766, 'name': 'CA Mineiro', 'shortName': 'Mineiro', 'tla': 'CAM', 'crest': 'https://crests.football-data.org/1766.png'}, 'awayTeam': {'id': 2071, 'name': 'CA San Lorenzo de Almagro', 'shortName': 'San Lorenzo', 'tla': 'SLO', 'crest': 'https://crests.football-data.org/2071.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 0}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2220, 'name': 'South America', 'code': 'SAM', 'flag': 'https://crests.football-data.org/CLI.svg'}, 'competition': {'id': 2152, 'name': 'Copa Libertadores', 'code': 'CLI', 'type': 'CUP', 'emblem': 'https://crests.football-data.org/CLI.svg'}, 'season': {'id': 1644, 'startDate': '2024-02-07', 'endDate': '2024-10-31', 'currentMatchday': 6, 'winner': None}, 'id': 517545, 'utcDate': '2024-08-21T00:30:00Z', 'status': 'FINISHED', 'matchday': 2, 'stage': 'LAST_16', 'group': None, 'lastUpdated': '2024-11-14T20:21:09Z', 'homeTeam': {'id': 4439, 'name': 'CDP Junior FC', 'shortName': 'Junior', 'tla': 'ATL', 'crest': 'https://crests.football-data.org/4439.png'}, 'awayTeam': {'id': 4410, 'name': 'CSD Colo-Colo', 'shortName': 'Colo-Colo', 'tla': 'COL', 'crest': 'https://crests.football-data.org/4410.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 2}, 'halfTime': {'home': 1, 'away': 1}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2220, 'name': 'South America', 'code': 'SAM', 'flag': 'https://crests.football-data.org/CLI.svg'}, 'competition': {'id': 2152, 'name': 'Copa Libertadores', 'code': 'CLI', 'type': 'CUP', 'emblem': 'https://crests.football-data.org/CLI.svg'}, 'season': {'id': 1644, 'startDate': '2024-02-07', 'endDate': '2024-10-31', 'currentMatchday': 6, 'winner': None}, 'id': 517548, 'utcDate': '2024-08-21T22:00:00Z', 'status': 'FINISHED', 'matchday': 2, 'stage': 'LAST_16', 'group': None, 'lastUpdated': '2024-11-14T20:21:09Z', 'homeTeam': {'id': 4267, 'name': 'Club The Strongest', 'shortName': 'The Strongest', 'tla': 'STR', 'crest': 'https://crests.football-data.org/4267.png'}, 'awayTeam': {'id': 5184, 'name': 'CA Peñarol', 'shortName': 'Peñarol', 'tla': 'PEN', 'crest': 'https://crests.football-data.org/5184.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 0}, 'halfTime': {'home': 1, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2220, 'name': 'South America', 'code': 'SAM', 'flag': 'https://crests.football-data.org/CLI.svg'}, 'competition': {'id': 2152, 'name': 'Copa Libertadores', 'code': 'CLI', 'type': 'CUP', 'emblem': 'https://crests.football-data.org/CLI.svg'}, 'season': {'id': 1644, 'startDate': '2024-02-07', 'endDate': '2024-10-31', 'currentMatchday': 6, 'winner': None}, 'id': 517544, 'utcDate': '2024-08-22T00:30:00Z', 'status': 'FINISHED', 'matchday': 2, 'stage': 'LAST_16', 'group': None, 'lastUpdated': '2024-11-14T20:21:09Z', 'homeTeam': {'id': 6667, 'name': 'CA River Plate', 'shortName': 'River Plate', 'tla': 'RI ...
# https://api.football-data.org/v4/matches/?dateFrom=2024-08-31&dateTo=2024-09-09
# {'filters': {'dateFrom': '2024-08-31', 'dateTo': '2024-09-09', 'permission': 'TIER_ONE'}, 'resultSet': {'count': 81, 'competitions': 'PL,ELC,BL1,DED,PPL,FL1,PD,SA,BSA', 'first': '2024-08-31', 'last': '2024-09-05', 'played': 81}, 'matches': [{'area': {'id': 2072, 'name': 'England', 'code': 'ENG', 'flag': 'https://crests.football-data.org/770.svg'}, 'competition': {'id': 2021, 'name': 'Premier League', 'code': 'PL', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/PL.png'}, 'season': {'id': 2287, 'startDate': '2024-08-16', 'endDate': '2025-05-25', 'currentMatchday': 29, 'winner': None}, 'id': 497430, 'utcDate': '2024-08-31T11:30:00Z', 'status': 'FINISHED', 'matchday': 3, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-16T10:21:09Z', 'homeTeam': {'id': 57, 'name': 'Arsenal FC', 'shortName': 'Arsenal', 'tla': 'ARS', 'crest': 'https://crests.football-data.org/57.png'}, 'awayTeam': {'id': 397, 'name': 'Brighton & Hove Albion FC', 'shortName': 'Brighton Hove', 'tla': 'BHA', 'crest': 'https://crests.football-data.org/397.png'}, 'score': {'winner': 'DRAW', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 1}, 'halfTime': {'home': 1, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 11443, 'name': 'Chris Kavanagh', 'type': 'REFEREE', 'nationality': 'England'}]}, {'area': {'id': 2072, 'name': 'England', 'code': 'ENG', 'flag': 'https://crests.football-data.org/770.svg'}, 'competition': {'id': 2016, 'name': 'Championship', 'code': 'ELC', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/ELC.png'}, 'season': {'id': 2301, 'startDate': '2024-08-09', 'endDate': '2025-05-03', 'currentMatchday': 38, 'winner': None}, 'id': 500482, 'utcDate': '2024-08-31T11:30:00Z', 'status': 'FINISHED', 'matchday': 4, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-16T10:21:09Z', 'homeTeam': {'id': 715, 'name': 'Cardiff City FC', 'shortName': 'Cardiff', 'tla': 'CAR', 'crest': 'https://crests.football-data.org/715.png'}, 'awayTeam': {'id': 343, 'name': 'Middlesbrough FC', 'shortName': 'Middlesbrough', 'tla': 'MID', 'crest': 'https://crests.football-data.org/343.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 2}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 11549, 'name': 'David Webb', 'type': 'REFEREE', 'nationality': 'England'}]}, {'area': {'id': 2072, 'name': 'England', 'code': 'ENG', 'flag': 'https://crests.football-data.org/770.svg'}, 'competition': {'id': 2016, 'name': 'Championship', 'code': 'ELC', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/ELC.png'}, 'season': {'id': 2301, 'startDate': '2024-08-09', 'endDate': '2025-05-03', 'currentMatchday': 38, 'winner': None}, 'id': 500481, 'utcDate': '2024-08-31T11:30:00Z', 'status': 'FINISHED', 'matchday': 4, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-16T10:21:09Z', 'homeTeam': {'id': 328, 'name': 'Burnley FC', 'shortName': 'Burnley', 'tla': 'BUR', 'crest': 'https://crests.football-data.org/328.png'}, 'awayTeam': {'id': 59, 'name': 'Blackburn Rovers FC', 'shortName': 'Blackburn', 'tla': 'BLA', 'crest': 'https://crests.football-data.org/59.png'}, 'score': {'winner': 'DRAW', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 1}, 'halfTime': {'home': 1, 'away': 1}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 11378, 'name': 'Tony Harrington', 'type': 'REFEREE', 'nationality': 'England'}]}, {'area': {'id': 2072, 'name': 'England', 'code': 'ENG', 'flag': 'https://crests.football-data.org/770.svg'}, 'competition': {'id': 2016, 'name': 'Championship', 'code': 'ELC', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/ELC.png'}, 'season': {'id': 2301, 'startDate': '2024-08-09', 'endDate': '2025-05-03', 'currentMatchday': 38, 'winner': None}, 'id': 500483, 'utcDate': '2024 ...
# https://api.football-data.org/v4/matches/?dateFrom=2024-09-10&dateTo=2024-09-19
# {'filters': {'dateFrom': '2024-09-10', 'dateTo': '2024-09-19', 'permission': 'TIER_ONE'}, 'resultSet': {'count': 106, 'competitions': 'BSA,BL1,FL1,ELC,PD,PPL,PL,SA,DED,CL,CLI', 'first': '2024-09-11', 'last': '2024-09-18', 'played': 106}, 'matches': [{'area': {'id': 2032, 'name': 'Brazil', 'code': 'BRA', 'flag': 'https://crests.football-data.org/764.svg'}, 'competition': {'id': 2013, 'name': 'Campeonato Brasileiro Série A', 'code': 'BSA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/bsa.png'}, 'season': {'id': 2257, 'startDate': '2024-04-13', 'endDate': '2024-12-08', 'currentMatchday': 38, 'winner': None}, 'id': 493939, 'utcDate': '2024-09-11T22:30:00Z', 'status': 'FINISHED', 'matchday': 19, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2024-12-22T20:20:40Z', 'homeTeam': {'id': 6684, 'name': 'SC Internacional', 'shortName': 'Internacional', 'tla': 'SCI', 'crest': 'https://crests.football-data.org/6684.png'}, 'awayTeam': {'id': 3984, 'name': 'Fortaleza EC', 'shortName': 'Fortaleza', 'tla': 'FEC', 'crest': 'https://crests.football-data.org/3984.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 2, 'away': 1}, 'halfTime': {'home': 1, 'away': 1}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2088, 'name': 'Germany', 'code': 'DEU', 'flag': 'https://crests.football-data.org/759.svg'}, 'competition': {'id': 2002, 'name': 'Bundesliga', 'code': 'BL1', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/BL1.png'}, 'season': {'id': 2308, 'startDate': '2024-08-23', 'endDate': '2025-05-17', 'currentMatchday': 26, 'winner': None}, 'id': 502390, 'utcDate': '2024-09-13T18:30:00Z', 'status': 'FINISHED', 'matchday': 3, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:18Z', 'homeTeam': {'id': 4, 'name': 'Borussia Dortmund', 'shortName': 'Dortmund', 'tla': 'BVB', 'crest': 'https://crests.football-data.org/4.png'}, 'awayTeam': {'id': 44, 'name': '1. FC Heidenheim 1846', 'shortName': 'Heidenheim', 'tla': 'HEI', 'crest': 'https://crests.football-data.org/44.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 4, 'away': 2}, 'halfTime': {'home': 3, 'away': 1}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 57519, 'name': 'Robert Schröder', 'type': 'REFEREE', 'nationality': 'Germany'}]}, {'area': {'id': 2081, 'name': 'France', 'code': 'FRA', 'flag': 'https://crests.football-data.org/773.svg'}, 'competition': {'id': 2015, 'name': 'Ligue 1', 'code': 'FL1', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/FL1.png'}, 'season': {'id': 2290, 'startDate': '2024-08-18', 'endDate': '2025-05-18', 'currentMatchday': 26, 'winner': None}, 'id': 497984, 'utcDate': '2024-09-13T18:45:00Z', 'status': 'FINISHED', 'matchday': 4, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTeam': {'id': 527, 'name': 'AS Saint-Étienne', 'shortName': 'Saint-Étienne', 'tla': 'ASS', 'crest': 'https://crests.football-data.org/527.png'}, 'awayTeam': {'id': 521, 'name': 'Lille OSC', 'shortName': 'Lille', 'tla': 'LIL', 'crest': 'https://crests.football-data.org/521.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 0}, 'halfTime': {'home': 1, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 43918, 'name': 'François Letexier', 'type': 'REFEREE', 'nationality': 'France'}]}, {'area': {'id': 2072, 'name': 'England', 'code': 'ENG', 'flag': 'https://crests.football-data.org/770.svg'}, 'competition': {'id': 2016, 'name': 'Championship', 'code': 'ELC', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/ELC.png'}, 'season': {'id': 2301, 'startDate': '2024-08-09', 'endDate': '2025-05-03', 'currentMatchday': 38, 'winner': None}, 'id': 500495, 'utcDate': '2024-09-13T19:00:00Z', 'status': 'FINISHED', 'matchday ...
# https://api.football-data.org/v4/matches/?dateFrom=2024-09-20&dateTo=2024-09-29
# {'filters': {'dateFrom': '2024-09-20', 'dateTo': '2024-09-29', 'permission': 'TIER_ONE'}, 'resultSet': {'count': 151, 'competitions': 'SA,DED,BL1,FL1,PD,ELC,PPL,PL,BSA,CLI', 'first': '2024-09-20', 'last': '2024-09-29', 'played': 151}, 'matches': [{'area': {'id': 2114, 'name': 'Italy', 'code': 'ITA', 'flag': 'https://crests.football-data.org/784.svg'}, 'competition': {'id': 2019, 'name': 'Serie A', 'code': 'SA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/SA.png'}, 'season': {'id': 2310, 'startDate': '2024-08-18', 'endDate': '2025-05-25', 'currentMatchday': 29, 'winner': None}, 'id': 503084, 'utcDate': '2024-09-20T16:30:00Z', 'status': 'FINISHED', 'matchday': 5, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTeam': {'id': 104, 'name': 'Cagliari Calcio', 'shortName': 'Cagliari', 'tla': 'CAG', 'crest': 'https://crests.football-data.org/104.png'}, 'awayTeam': {'id': 445, 'name': 'Empoli FC', 'shortName': 'Empoli', 'tla': 'EMP', 'crest': 'https://crests.football-data.org/445.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 2}, 'halfTime': {'home': 0, 'away': 1}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 57826, 'name': 'Simone Sozza', 'type': 'REFEREE', 'nationality': 'Italy'}]}, {'area': {'id': 2163, 'name': 'Netherlands', 'code': 'NLD', 'flag': 'https://crests.football-data.org/8601.svg'}, 'competition': {'id': 2003, 'name': 'Eredivisie', 'code': 'DED', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/ED.png'}, 'season': {'id': 2293, 'startDate': '2024-08-09', 'endDate': '2025-05-18', 'currentMatchday': 26, 'winner': None}, 'id': 499038, 'utcDate': '2024-09-20T18:00:00Z', 'status': 'FINISHED', 'matchday': 6, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:18Z', 'homeTeam': {'id': 684, 'name': 'PEC Zwolle', 'shortName': 'Zwolle', 'tla': 'ZWO', 'crest': 'https://crests.football-data.org/684.png'}, 'awayTeam': {'id': 682, 'name': 'AZ', 'shortName': 'AZ', 'tla': 'AZ', 'crest': 'https://crests.football-data.org/682.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 2}, 'halfTime': {'home': 0, 'away': 1}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2088, 'name': 'Germany', 'code': 'DEU', 'flag': 'https://crests.football-data.org/759.svg'}, 'competition': {'id': 2002, 'name': 'Bundesliga', 'code': 'BL1', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/BL1.png'}, 'season': {'id': 2308, 'startDate': '2024-08-23', 'endDate': '2025-05-17', 'currentMatchday': 26, 'winner': None}, 'id': 502403, 'utcDate': '2024-09-20T18:30:00Z', 'status': 'FINISHED', 'matchday': 4, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:18Z', 'homeTeam': {'id': 16, 'name': 'FC Augsburg', 'shortName': 'Augsburg', 'tla': 'FCA', 'crest': 'https://crests.football-data.org/16.png'}, 'awayTeam': {'id': 15, 'name': '1. FSV Mainz 05', 'shortName': 'Mainz', 'tla': 'M05', 'crest': 'https://crests.football-data.org/15.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 2, 'away': 3}, 'halfTime': {'home': 1, 'away': 2}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 57515, 'name': 'Sören Storks', 'type': 'REFEREE', 'nationality': 'Germany'}]}, {'area': {'id': 2114, 'name': 'Italy', 'code': 'ITA', 'flag': 'https://crests.football-data.org/784.svg'}, 'competition': {'id': 2019, 'name': 'Serie A', 'code': 'SA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/SA.png'}, 'season': {'id': 2310, 'startDate': '2024-08-18', 'endDate': '2025-05-25', 'currentMatchday': 29, 'winner': None}, 'id': 503086, 'utcDate': '2024-09-20T18:45:00Z', 'status': 'FINISHED', 'matchday': 5, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTe ...
# https://api.football-data.org/v4/matches/?dateFrom=2024-09-30&dateTo=2024-10-09
# {'filters': {'dateFrom': '2024-09-30', 'dateTo': '2024-10-09', 'permission': 'TIER_ONE'}, 'resultSet': {'count': 121, 'competitions': 'SA,PL,PD,PPL,CL,ELC,BSA,DED,BL1,FL1', 'first': '2024-09-30', 'last': '2024-10-06', 'played': 121}, 'matches': [{'area': {'id': 2114, 'name': 'Italy', 'code': 'ITA', 'flag': 'https://crests.football-data.org/784.svg'}, 'competition': {'id': 2019, 'name': 'Serie A', 'code': 'SA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/SA.png'}, 'season': {'id': 2310, 'startDate': '2024-08-18', 'endDate': '2025-05-25', 'currentMatchday': 29, 'winner': None}, 'id': 503099, 'utcDate': '2024-09-30T18:45:00Z', 'status': 'FINISHED', 'matchday': 6, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTeam': {'id': 112, 'name': 'Parma Calcio 1913', 'shortName': 'Parma', 'tla': 'PAR', 'crest': 'https://crests.football-data.org/112.png'}, 'awayTeam': {'id': 104, 'name': 'Cagliari Calcio', 'shortName': 'Cagliari', 'tla': 'CAG', 'crest': 'https://crests.football-data.org/104.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 2, 'away': 3}, 'halfTime': {'home': 0, 'away': 1}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 11129, 'name': 'Francesco Fourneau', 'type': 'REFEREE', 'nationality': 'Italy'}]}, {'area': {'id': 2072, 'name': 'England', 'code': 'ENG', 'flag': 'https://crests.football-data.org/770.svg'}, 'competition': {'id': 2021, 'name': 'Premier League', 'code': 'PL', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/PL.png'}, 'season': {'id': 2287, 'startDate': '2024-08-16', 'endDate': '2025-05-25', 'currentMatchday': 29, 'winner': None}, 'id': 497460, 'utcDate': '2024-09-30T19:00:00Z', 'status': 'FINISHED', 'matchday': 6, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTeam': {'id': 1044, 'name': 'AFC Bournemouth', 'shortName': 'Bournemouth', 'tla': 'BOU', 'crest': 'https://crests.football-data.org/bournemouth.png'}, 'awayTeam': {'id': 340, 'name': 'Southampton FC', 'shortName': 'Southampton', 'tla': 'SOU', 'crest': 'https://crests.football-data.org/340.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 3, 'away': 1}, 'halfTime': {'home': 3, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 11605, 'name': 'Michael Oliver', 'type': 'REFEREE', 'nationality': 'England'}]}, {'area': {'id': 2224, 'name': 'Spain', 'code': 'ESP', 'flag': 'https://crests.football-data.org/760.svg'}, 'competition': {'id': 2014, 'name': 'Primera Division', 'code': 'PD', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/laliga.png'}, 'season': {'id': 2292, 'startDate': '2024-08-18', 'endDate': '2025-05-25', 'currentMatchday': 28, 'winner': None}, 'id': 498688, 'utcDate': '2024-09-30T19:00:00Z', 'status': 'FINISHED', 'matchday': 8, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTeam': {'id': 94, 'name': 'Villarreal CF', 'shortName': 'Villarreal', 'tla': 'VIL', 'crest': 'https://crests.football-data.org/94.png'}, 'awayTeam': {'id': 275, 'name': 'UD Las Palmas', 'shortName': 'Las Palmas', 'tla': 'LPA', 'crest': 'https://crests.football-data.org/275.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 3, 'away': 1}, 'halfTime': {'home': 1, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 207105, 'name': 'Mario Melero López', 'type': 'REFEREE', 'nationality': 'Spain'}]}, {'area': {'id': 2187, 'name': 'Portugal', 'code': 'POR', 'flag': 'https://crests.football-data.org/765.svg'}, 'competition': {'id': 2017, 'name': 'Primeira Liga', 'code': 'PPL', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/PPL.png'}, 'season': {'id': 2312, 'startDate': '2024-08-11', 'endDate': '2025-05-17', 'currentMatchday': 26, 'winner': None}, 'id': 50 ...
# https://api.football-data.org/v4/matches/?dateFrom=2024-10-10&dateTo=2024-10-19
# {'filters': {'dateFrom': '2024-10-10', 'dateTo': '2024-10-19', 'permission': 'TIER_ONE'}, 'resultSet': {'count': 10, 'competitions': 'BSA,BL1,FL1,PD,ELC', 'first': '2024-10-17', 'last': '2024-10-18', 'played': 10}, 'matches': [{'area': {'id': 2032, 'name': 'Brazil', 'code': 'BRA', 'flag': 'https://crests.football-data.org/764.svg'}, 'competition': {'id': 2013, 'name': 'Campeonato Brasileiro Série A', 'code': 'BSA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/bsa.png'}, 'season': {'id': 2257, 'startDate': '2024-04-13', 'endDate': '2024-12-08', 'currentMatchday': 38, 'winner': None}, 'id': 494051, 'utcDate': '2024-10-17T00:45:00Z', 'status': 'FINISHED', 'matchday': 30, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2024-12-22T20:20:40Z', 'homeTeam': {'id': 1776, 'name': 'São Paulo FC', 'shortName': 'São Paulo', 'tla': 'PAU', 'crest': 'https://crests.football-data.org/1776.png'}, 'awayTeam': {'id': 1780, 'name': 'CR Vasco da Gama', 'shortName': 'Vasco da Gama', 'tla': 'VAS', 'crest': 'https://crests.football-data.org/1780.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 3, 'away': 0}, 'halfTime': {'home': 1, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2032, 'name': 'Brazil', 'code': 'BRA', 'flag': 'https://crests.football-data.org/764.svg'}, 'competition': {'id': 2013, 'name': 'Campeonato Brasileiro Série A', 'code': 'BSA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/bsa.png'}, 'season': {'id': 2257, 'startDate': '2024-04-13', 'endDate': '2024-12-08', 'currentMatchday': 38, 'winner': None}, 'id': 494048, 'utcDate': '2024-10-17T00:45:00Z', 'status': 'FINISHED', 'matchday': 30, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2024-12-22T20:20:40Z', 'homeTeam': {'id': 3984, 'name': 'Fortaleza EC', 'shortName': 'Fortaleza', 'tla': 'FEC', 'crest': 'https://crests.football-data.org/3984.png'}, 'awayTeam': {'id': 1766, 'name': 'CA Mineiro', 'shortName': 'Mineiro', 'tla': 'CAM', 'crest': 'https://crests.football-data.org/1766.png'}, 'score': {'winner': 'DRAW', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 1}, 'halfTime': {'home': 1, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2032, 'name': 'Brazil', 'code': 'BRA', 'flag': 'https://crests.football-data.org/764.svg'}, 'competition': {'id': 2013, 'name': 'Campeonato Brasileiro Série A', 'code': 'BSA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/bsa.png'}, 'season': {'id': 2257, 'startDate': '2024-04-13', 'endDate': '2024-12-08', 'currentMatchday': 38, 'winner': None}, 'id': 494047, 'utcDate': '2024-10-17T23:00:00Z', 'status': 'FINISHED', 'matchday': 30, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2024-12-22T20:20:40Z', 'homeTeam': {'id': 1783, 'name': 'CR Flamengo', 'shortName': 'Flamengo', 'tla': 'FLA', 'crest': 'https://crests.football-data.org/1783.png'}, 'awayTeam': {'id': 1765, 'name': 'Fluminense FC', 'shortName': 'Fluminense', 'tla': 'FLU', 'crest': 'https://crests.football-data.org/1765.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 2}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2032, 'name': 'Brazil', 'code': 'BRA', 'flag': 'https://crests.football-data.org/764.svg'}, 'competition': {'id': 2013, 'name': 'Campeonato Brasileiro Série A', 'code': 'BSA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/bsa.png'}, 'season': {'id': 2257, 'startDate': '2024-04-13', 'endDate': '2024-12-08', 'currentMatchday': 38, 'winner': None}, 'id': 494045, 'utcDate': '2024-10-17T23:00:00Z', 'status': 'FINISHED', 'matchday': 30, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2024-12-22T20:20:40Z', 'homeTeam': {'id': 1779, 'name': 'SC Corinthians Paulista' ...
# https://api.football-data.org/v4/matches/?dateFrom=2024-10-20&dateTo=2024-10-29
# {'filters': {'dateFrom': '2024-10-20', 'dateTo': '2024-10-29', 'permission': 'TIER_ONE'}, 'resultSet': {'count': 148, 'competitions': 'DED,SA,PD,PL,FL1,BL1,ELC,BSA,CL,CLI,PPL', 'first': '2024-10-20', 'last': '2024-10-29', 'played': 148}, 'matches': [{'area': {'id': 2163, 'name': 'Netherlands', 'code': 'NLD', 'flag': 'https://crests.football-data.org/8601.svg'}, 'competition': {'id': 2003, 'name': 'Eredivisie', 'code': 'DED', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/ED.png'}, 'season': {'id': 2293, 'startDate': '2024-08-09', 'endDate': '2025-05-18', 'currentMatchday': 26, 'winner': None}, 'id': 499070, 'utcDate': '2024-10-20T10:15:00Z', 'status': 'FINISHED', 'matchday': 9, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:18Z', 'homeTeam': {'id': 672, 'name': 'Willem II Tilburg', 'shortName': 'Willem II', 'tla': 'WII', 'crest': 'https://crests.football-data.org/672.png'}, 'awayTeam': {'id': 1920, 'name': 'Fortuna Sittard', 'shortName': 'Sittard', 'tla': 'SIT', 'crest': 'https://crests.football-data.org/1920.png'}, 'score': {'winner': 'DRAW', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 0}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 17141, 'name': 'Rob Dieperink', 'type': 'REFEREE', 'nationality': 'Netherlands'}]}, {'area': {'id': 2114, 'name': 'Italy', 'code': 'ITA', 'flag': 'https://crests.football-data.org/784.svg'}, 'competition': {'id': 2019, 'name': 'Serie A', 'code': 'SA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/SA.png'}, 'season': {'id': 2310, 'startDate': '2024-08-18', 'endDate': '2025-05-25', 'currentMatchday': 29, 'winner': None}, 'id': 503115, 'utcDate': '2024-10-20T10:30:00Z', 'status': 'FINISHED', 'matchday': 8, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTeam': {'id': 445, 'name': 'Empoli FC', 'shortName': 'Empoli', 'tla': 'EMP', 'crest': 'https://crests.football-data.org/445.png'}, 'awayTeam': {'id': 113, 'name': 'SSC Napoli', 'shortName': 'Napoli', 'tla': 'NAP', 'crest': 'https://crests.football-data.org/113.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 1}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 11006, 'name': 'Rosario Abisso', 'type': 'REFEREE', 'nationality': 'Italy'}]}, {'area': {'id': 2224, 'name': 'Spain', 'code': 'ESP', 'flag': 'https://crests.football-data.org/760.svg'}, 'competition': {'id': 2014, 'name': 'Primera Division', 'code': 'PD', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/laliga.png'}, 'season': {'id': 2292, 'startDate': '2024-08-18', 'endDate': '2025-05-25', 'currentMatchday': 28, 'winner': None}, 'id': 498711, 'utcDate': '2024-10-20T12:00:00Z', 'status': 'FINISHED', 'matchday': 10, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTeam': {'id': 89, 'name': 'RCD Mallorca', 'shortName': 'Mallorca', 'tla': 'MAL', 'crest': 'https://crests.football-data.org/89.png'}, 'awayTeam': {'id': 87, 'name': 'Rayo Vallecano de Madrid', 'shortName': 'Rayo Vallecano', 'tla': 'RAY', 'crest': 'https://crests.football-data.org/87.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 0}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 80747, 'name': 'Javier Alberola Rojas', 'type': 'REFEREE', 'nationality': None}]}, {'area': {'id': 2163, 'name': 'Netherlands', 'code': 'NLD', 'flag': 'https://crests.football-data.org/8601.svg'}, 'competition': {'id': 2003, 'name': 'Eredivisie', 'code': 'DED', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/ED.png'}, 'season': {'id': 2293, 'startDate': '2024-08-09', 'endDate': '2025-05-18', 'currentMatchday': 26, 'winner': None}, 'id': 499072, 'utcDate ...
# https://api.football-data.org/v4/matches/?dateFrom=2024-10-30&dateTo=2024-11-08
# {'filters': {'dateFrom': '2024-10-30', 'dateTo': '2024-11-08', 'permission': 'TIER_ONE'}, 'resultSet': {'count': 128, 'competitions': 'CLI,DED,SA,BSA,FL1,BL1,PD,ELC,PPL,PL,CL', 'first': '2024-10-30', 'last': '2024-11-07', 'played': 128}, 'matches': [{'area': {'id': 2220, 'name': 'South America', 'code': 'SAM', 'flag': 'https://crests.football-data.org/CLI.svg'}, 'competition': {'id': 2152, 'name': 'Copa Libertadores', 'code': 'CLI', 'type': 'CUP', 'emblem': 'https://crests.football-data.org/CLI.svg'}, 'season': {'id': 1644, 'startDate': '2024-02-07', 'endDate': '2024-10-31', 'currentMatchday': 6, 'winner': None}, 'id': 525166, 'utcDate': '2024-10-30T00:45:00Z', 'status': 'FINISHED', 'matchday': 2, 'stage': 'SEMI_FINALS', 'group': None, 'lastUpdated': '2024-11-14T20:21:09Z', 'homeTeam': {'id': 6667, 'name': 'CA River Plate', 'shortName': 'River Plate', 'tla': 'RIV', 'crest': 'https://crests.football-data.org/6667.png'}, 'awayTeam': {'id': 1766, 'name': 'CA Mineiro', 'shortName': 'Mineiro', 'tla': 'CAM', 'crest': 'https://crests.football-data.org/1766.png'}, 'score': {'winner': 'DRAW', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 0}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2163, 'name': 'Netherlands', 'code': 'NLD', 'flag': 'https://crests.football-data.org/8601.svg'}, 'competition': {'id': 2003, 'name': 'Eredivisie', 'code': 'DED', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/ED.png'}, 'season': {'id': 2293, 'startDate': '2024-08-09', 'endDate': '2025-05-18', 'currentMatchday': 26, 'winner': None}, 'id': 499026, 'utcDate': '2024-10-30T17:00:00Z', 'status': 'FINISHED', 'matchday': 4, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:18Z', 'homeTeam': {'id': 675, 'name': 'Feyenoord Rotterdam', 'shortName': 'Feyenoord', 'tla': 'FEY', 'crest': 'https://crests.football-data.org/675.png'}, 'awayTeam': {'id': 678, 'name': 'AFC Ajax', 'shortName': 'Ajax', 'tla': 'AJA', 'crest': 'https://crests.football-data.org/678.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 2}, 'halfTime': {'home': 0, 'away': 2}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 43899, 'name': 'Danny Makkelie', 'type': 'REFEREE', 'nationality': 'Netherlands'}]}, {'area': {'id': 2114, 'name': 'Italy', 'code': 'ITA', 'flag': 'https://crests.football-data.org/784.svg'}, 'competition': {'id': 2019, 'name': 'Serie A', 'code': 'SA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/SA.png'}, 'season': {'id': 2310, 'startDate': '2024-08-18', 'endDate': '2025-05-25', 'currentMatchday': 29, 'winner': None}, 'id': 503136, 'utcDate': '2024-10-30T17:30:00Z', 'status': 'FINISHED', 'matchday': 10, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTeam': {'id': 445, 'name': 'Empoli FC', 'shortName': 'Empoli', 'tla': 'EMP', 'crest': 'https://crests.football-data.org/445.png'}, 'awayTeam': {'id': 108, 'name': 'FC Internazionale Milano', 'shortName': 'Inter', 'tla': 'INT', 'crest': 'https://crests.football-data.org/108.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 3}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 57762, 'name': 'Matteo Marchetti', 'type': 'REFEREE', 'nationality': 'Italy'}]}, {'area': {'id': 2114, 'name': 'Italy', 'code': 'ITA', 'flag': 'https://crests.football-data.org/784.svg'}, 'competition': {'id': 2019, 'name': 'Serie A', 'code': 'SA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/SA.png'}, 'season': {'id': 2310, 'startDate': '2024-08-18', 'endDate': '2025-05-25', 'currentMatchday': 29, 'winner': None}, 'id': 503142, 'utcDate': '2024-10-30T17:30:00Z', 'status': 'FINISHED', 'matchday': 10, 'stage': 'REGULAR_SEASON', 'group' ...
# https://api.football-data.org/v4/matches/?dateFrom=2024-11-09&dateTo=2024-11-18
# {'filters': {'dateFrom': '2024-11-09', 'dateTo': '2024-11-18', 'permission': 'TIER_ONE'}, 'resultSet': {'count': 79, 'competitions': 'BSA,ELC,PD,SA,BL1,PL,PPL,DED,FL1', 'first': '2024-11-09', 'last': '2024-11-16', 'played': 79}, 'matches': [{'area': {'id': 2032, 'name': 'Brazil', 'code': 'BRA', 'flag': 'https://crests.football-data.org/764.svg'}, 'competition': {'id': 2013, 'name': 'Campeonato Brasileiro Série A', 'code': 'BSA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/bsa.png'}, 'season': {'id': 2257, 'startDate': '2024-04-13', 'endDate': '2024-12-08', 'currentMatchday': 38, 'winner': None}, 'id': 494080, 'utcDate': '2024-11-09T00:30:00Z', 'status': 'FINISHED', 'matchday': 33, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2024-12-22T20:20:40Z', 'homeTeam': {'id': 1769, 'name': 'SE Palmeiras', 'shortName': 'Palmeiras', 'tla': 'PAL', 'crest': 'https://crests.football-data.org/1769.png'}, 'awayTeam': {'id': 1767, 'name': 'Grêmio FBPA', 'shortName': 'Grêmio', 'tla': 'FBP', 'crest': 'https://crests.football-data.org/1767.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 0}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2072, 'name': 'England', 'code': 'ENG', 'flag': 'https://crests.football-data.org/770.svg'}, 'competition': {'id': 2016, 'name': 'Championship', 'code': 'ELC', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/ELC.png'}, 'season': {'id': 2301, 'startDate': '2024-08-09', 'endDate': '2025-05-03', 'currentMatchday': 38, 'winner': None}, 'id': 500618, 'utcDate': '2024-11-09T12:30:00Z', 'status': 'FINISHED', 'matchday': 15, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTeam': {'id': 343, 'name': 'Middlesbrough FC', 'shortName': 'Middlesbrough', 'tla': 'MID', 'crest': 'https://crests.football-data.org/343.png'}, 'awayTeam': {'id': 389, 'name': 'Luton Town FC', 'shortName': 'Luton Town', 'tla': 'LUT', 'crest': 'https://crests.football-data.org/389.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 5, 'away': 1}, 'halfTime': {'home': 2, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 11378, 'name': 'Tony Harrington', 'type': 'REFEREE', 'nationality': 'England'}]}, {'area': {'id': 2072, 'name': 'England', 'code': 'ENG', 'flag': 'https://crests.football-data.org/770.svg'}, 'competition': {'id': 2016, 'name': 'Championship', 'code': 'ELC', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/ELC.png'}, 'season': {'id': 2301, 'startDate': '2024-08-09', 'endDate': '2025-05-03', 'currentMatchday': 38, 'winner': None}, 'id': 500614, 'utcDate': '2024-11-09T12:30:00Z', 'status': 'FINISHED', 'matchday': 15, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTeam': {'id': 715, 'name': 'Cardiff City FC', 'shortName': 'Cardiff', 'tla': 'CAR', 'crest': 'https://crests.football-data.org/715.png'}, 'awayTeam': {'id': 59, 'name': 'Blackburn Rovers FC', 'shortName': 'Blackburn', 'tla': 'BLA', 'crest': 'https://crests.football-data.org/59.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 3}, 'halfTime': {'home': 0, 'away': 1}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 9382, 'name': 'Gavin Ward', 'type': 'REFEREE', 'nationality': 'England'}]}, {'area': {'id': 2072, 'name': 'England', 'code': 'ENG', 'flag': 'https://crests.football-data.org/770.svg'}, 'competition': {'id': 2016, 'name': 'Championship', 'code': 'ELC', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/ELC.png'}, 'season': {'id': 2301, 'startDate': '2024-08-09', 'endDate': '2025-05-03', 'currentMatchday': 38, 'winner': None}, 'id': 500622, 'utcDate': '2024-11-09T12:30:00Z', 'status': 'FINISHED', 'matchday': 15, 'sta ...
# https://api.football-data.org/v4/matches/?dateFrom=2024-11-19&dateTo=2024-11-28
# ...
# https://api.football-data.org/v4/matches/?dateFrom=2025-02-17&dateTo=2025-02-26
# {'filters': {'dateFrom': '2025-02-17', 'dateTo': '2025-02-26', 'permission': 'TIER_ONE'}, 'resultSet': {'count': 103, 'competitions': 'SA,PD,ELC,PPL,CL,CLI,PL,BL1,FL1,DED', 'first': '2025-02-17', 'last': '2025-02-25', 'played': 103}, 'matches': [{'area': {'id': 2114, 'name': 'Italy', 'code': 'ITA', 'flag': 'https://crests.football-data.org/784.svg'}, 'competition': {'id': 2019, 'name': 'Serie A', 'code': 'SA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/SA.png'}, 'season': {'id': 2310, 'startDate': '2024-08-18', 'endDate': '2025-05-25', 'currentMatchday': 29, 'winner': None}, 'id': 503286, 'utcDate': '2025-02-17T19:45:00Z', 'status': 'FINISHED', 'matchday': 25, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTeam': {'id': 107, 'name': 'Genoa CFC', 'shortName': 'Genoa', 'tla': 'GEN', 'crest': 'https://crests.football-data.org/107.png'}, 'awayTeam': {'id': 454, 'name': 'Venezia FC', 'shortName': 'Venezia FC', 'tla': 'VEN', 'crest': 'https://crests.football-data.org/454.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 2, 'away': 0}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 11119, 'name': 'Livio Marinelli', 'type': 'REFEREE', 'nationality': 'Italy'}]}, {'area': {'id': 2224, 'name': 'Spain', 'code': 'ESP', 'flag': 'https://crests.football-data.org/760.svg'}, 'competition': {'id': 2014, 'name': 'Primera Division', 'code': 'PD', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/laliga.png'}, 'season': {'id': 2292, 'startDate': '2024-08-18', 'endDate': '2025-05-25', 'currentMatchday': 28, 'winner': None}, 'id': 498847, 'utcDate': '2025-02-17T20:00:00Z', 'status': 'FINISHED', 'matchday': 24, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTeam': {'id': 81, 'name': 'FC Barcelona', 'shortName': 'Barça', 'tla': 'FCB', 'crest': 'https://crests.football-data.org/81.png'}, 'awayTeam': {'id': 87, 'name': 'Rayo Vallecano de Madrid', 'shortName': 'Rayo Vallecano', 'tla': 'RAY', 'crest': 'https://crests.football-data.org/87.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 0}, 'halfTime': {'home': 1, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 207105, 'name': 'Mario Melero López', 'type': 'REFEREE', 'nationality': 'Spain'}]}, {'area': {'id': 2072, 'name': 'England', 'code': 'ENG', 'flag': 'https://crests.football-data.org/770.svg'}, 'competition': {'id': 2016, 'name': 'Championship', 'code': 'ELC', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/ELC.png'}, 'season': {'id': 2301, 'startDate': '2024-08-09', 'endDate': '2025-05-03', 'currentMatchday': 38, 'winner': None}, 'id': 500832, 'utcDate': '2025-02-17T20:00:00Z', 'status': 'FINISHED', 'matchday': 33, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTeam': {'id': 341, 'name': 'Leeds United FC', 'shortName': 'Leeds United', 'tla': 'LEE', 'crest': 'https://crests.football-data.org/341.png'}, 'awayTeam': {'id': 71, 'name': 'Sunderland AFC', 'shortName': 'Sunderland', 'tla': 'SUN', 'crest': 'https://crests.football-data.org/71.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 2, 'away': 1}, 'halfTime': {'home': 0, 'away': 1}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 11585, 'name': 'Craig Pawson', 'type': 'REFEREE', 'nationality': 'England'}]}, {'area': {'id': 2187, 'name': 'Portugal', 'code': 'POR', 'flag': 'https://crests.football-data.org/765.svg'}, 'competition': {'id': 2017, 'name': 'Primeira Liga', 'code': 'PPL', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/PPL.png'}, 'season': {'id': 2312, 'startDate': '2024-08-11', 'endDate': '2025-05-17', 'currentMatchday': 26, 'winner': None}, 'id': 503833, 'utcDate':  ...
# https://api.football-data.org/v4/matches/?dateFrom=2025-02-27&dateTo=2025-03-08
# {'filters': {'dateFrom': '2025-02-27', 'dateTo': '2025-03-08', 'permission': 'TIER_ONE'}, 'resultSet': {'count': 90, 'competitions': 'CLI,SA,PL,DED,BL1,FL1,PD,ELC,PPL,CL', 'first': '2025-02-27', 'last': '2025-03-07', 'played': 90}, 'matches': [{'area': {'id': 2220, 'name': 'South America', 'code': 'SAM', 'flag': 'https://crests.football-data.org/CLI.svg'}, 'competition': {'id': 2152, 'name': 'Copa Libertadores', 'code': 'CLI', 'type': 'CUP', 'emblem': 'https://crests.football-data.org/CLI.svg'}, 'season': {'id': 2366, 'startDate': '2025-02-05', 'endDate': '2025-11-29', 'currentMatchday': 2, 'winner': None}, 'id': 526053, 'utcDate': '2025-02-27T00:30:00Z', 'status': 'FINISHED', 'matchday': 2, 'stage': 'ROUND_2', 'group': None, 'lastUpdated': '2025-03-19T02:45:16Z', 'homeTeam': {'id': 1779, 'name': 'SC Corinthians Paulista', 'shortName': 'Corinthians', 'tla': 'COR', 'crest': 'https://crests.football-data.org/1779.png'}, 'awayTeam': {'id': 9357, 'name': 'Universidad Central de Venezuela FC', 'shortName': None, 'tla': '', 'crest': 'https://crests.football-data.org/9357.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 3, 'away': 2}, 'halfTime': {'home': 2, 'away': 2}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2220, 'name': 'South America', 'code': 'SAM', 'flag': 'https://crests.football-data.org/CLI.svg'}, 'competition': {'id': 2152, 'name': 'Copa Libertadores', 'code': 'CLI', 'type': 'CUP', 'emblem': 'https://crests.football-data.org/CLI.svg'}, 'season': {'id': 2366, 'startDate': '2025-02-05', 'endDate': '2025-11-29', 'currentMatchday': 2, 'winner': None}, 'id': 526048, 'utcDate': '2025-02-27T00:30:00Z', 'status': 'FINISHED', 'matchday': 2, 'stage': 'ROUND_2', 'group': None, 'lastUpdated': '2025-03-19T02:45:16Z', 'homeTeam': {'id': 4520, 'name': 'Barcelona SC', 'shortName': 'Barcelona SC', 'tla': 'BAR', 'crest': 'https://crests.football-data.org/4520.png'}, 'awayTeam': {'id': 4524, 'name': 'CSCyD El Nacional', 'shortName': 'El Nacional', 'tla': 'ELN', 'crest': 'https://crests.football-data.org/4524.png'}, 'score': {'winner': 'DRAW', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 1}, 'halfTime': {'home': 0, 'away': 1}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2114, 'name': 'Italy', 'code': 'ITA', 'flag': 'https://crests.football-data.org/784.svg'}, 'competition': {'id': 2019, 'name': 'Serie A', 'code': 'SA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/SA.png'}, 'season': {'id': 2310, 'startDate': '2024-08-18', 'endDate': '2025-05-25', 'currentMatchday': 29, 'winner': None}, 'id': 503124, 'utcDate': '2025-02-27T19:45:00Z', 'status': 'FINISHED', 'matchday': 9, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTeam': {'id': 103, 'name': 'Bologna FC 1909', 'shortName': 'Bologna', 'tla': 'BOL', 'crest': 'https://crests.football-data.org/103.png'}, 'awayTeam': {'id': 98, 'name': 'AC Milan', 'shortName': 'Milan', 'tla': 'MIL', 'crest': 'https://crests.football-data.org/98.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 2, 'away': 1}, 'halfTime': {'home': 0, 'away': 1}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 11043, 'name': 'Maurizio Mariani', 'type': 'REFEREE', 'nationality': 'Italy'}]}, {'area': {'id': 2072, 'name': 'England', 'code': 'ENG', 'flag': 'https://crests.football-data.org/770.svg'}, 'competition': {'id': 2021, 'name': 'Premier League', 'code': 'PL', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/PL.png'}, 'season': {'id': 2287, 'startDate': '2024-08-16', 'endDate': '2025-05-25', 'currentMatchday': 29, 'winner': None}, 'id': 497676, 'utcDate': '2025-02-27T20:00:00Z', 'status': 'FINISHED', 'matchday': 27, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTeam': {' ...
# https://api.football-data.org/v4/matches/?dateFrom=2025-03-09&dateTo=2025-03-18
# {'filters': {'dateFrom': '2025-03-09', 'dateTo': '2025-03-18', 'permission': 'TIER_ONE'}, 'resultSet': {'count': 131, 'competitions': 'DED,SA,ELC,PD,PL,FL1,BL1,PPL,CL,CLI', 'first': '2025-03-09', 'last': '2025-03-16', 'played': 130}, 'matches': [{'area': {'id': 2163, 'name': 'Netherlands', 'code': 'NLD', 'flag': 'https://crests.football-data.org/8601.svg'}, 'competition': {'id': 2003, 'name': 'Eredivisie', 'code': 'DED', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/ED.png'}, 'season': {'id': 2293, 'startDate': '2024-08-09', 'endDate': '2025-05-18', 'currentMatchday': 26, 'winner': None}, 'id': 499217, 'utcDate': '2025-03-09T11:15:00Z', 'status': 'FINISHED', 'matchday': 25, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:18Z', 'homeTeam': {'id': 672, 'name': 'Willem II Tilburg', 'shortName': 'Willem II', 'tla': 'WII', 'crest': 'https://crests.football-data.org/672.png'}, 'awayTeam': {'id': 676, 'name': 'FC Utrecht', 'shortName': 'Utrecht', 'tla': 'UTR', 'crest': 'https://crests.football-data.org/676.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 2, 'away': 3}, 'halfTime': {'home': 1, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 9561, 'name': 'Allard Lindhout', 'type': 'REFEREE', 'nationality': 'Netherlands'}]}, {'area': {'id': 2114, 'name': 'Italy', 'code': 'ITA', 'flag': 'https://crests.football-data.org/784.svg'}, 'competition': {'id': 2019, 'name': 'Serie A', 'code': 'SA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/SA.png'}, 'season': {'id': 2310, 'startDate': '2024-08-18', 'endDate': '2025-05-25', 'currentMatchday': 29, 'winner': None}, 'id': 503316, 'utcDate': '2025-03-09T11:30:00Z', 'status': 'FINISHED', 'matchday': 28, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTeam': {'id': 450, 'name': 'Hellas Verona FC', 'shortName': 'Verona', 'tla': 'HVE', 'crest': 'https://crests.football-data.org/450.png'}, 'awayTeam': {'id': 103, 'name': 'Bologna FC 1909', 'shortName': 'Bologna', 'tla': 'BOL', 'crest': 'https://crests.football-data.org/103.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 2}, 'halfTime': {'home': 0, 'away': 1}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 11018, 'name': 'Antonio Rapuano', 'type': 'REFEREE', 'nationality': 'Italy'}]}, {'area': {'id': 2072, 'name': 'England', 'code': 'ENG', 'flag': 'https://crests.football-data.org/770.svg'}, 'competition': {'id': 2016, 'name': 'Championship', 'code': 'ELC', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/ELC.png'}, 'season': {'id': 2301, 'startDate': '2024-08-09', 'endDate': '2025-05-03', 'currentMatchday': 38, 'winner': None}, 'id': 500871, 'utcDate': '2025-03-09T12:00:00Z', 'status': 'FINISHED', 'matchday': 36, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-19T00:21:19Z', 'homeTeam': {'id': 325, 'name': 'Portsmouth FC', 'shortName': 'Portsmouth', 'tla': 'POR', 'crest': 'https://crests.football-data.org/325.png'}, 'awayTeam': {'id': 341, 'name': 'Leeds United FC', 'shortName': 'Leeds United', 'tla': 'LEE', 'crest': 'https://crests.football-data.org/341.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 0}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 11446, 'name': 'Robert Jones', 'type': 'REFEREE', 'nationality': 'England'}]}, {'area': {'id': 2224, 'name': 'Spain', 'code': 'ESP', 'flag': 'https://crests.football-data.org/760.svg'}, 'competition': {'id': 2014, 'name': 'Primera Division', 'code': 'PD', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/laliga.png'}, 'season': {'id': 2292, 'startDate': '2024-08-18', 'endDate': '2025-05-25', 'currentMatchday': 28, 'winner': None}, 'id': 498878, 'utcDat ...
# https://api.football-data.org/v4/matches/?dateFrom=2025-03-19&dateTo=2025-03-28
# {'filters': {'dateFrom': '2025-03-19', 'dateTo': '2025-03-28', 'permission': 'TIER_ONE'}, 'resultSet': {'count': 1, 'competitions': 'PD', 'first': '2025-03-27', 'last': '2025-03-27', 'played': 0}, 'matches': [{'area': {'id': 2224, 'name': 'Spain', 'code': 'ESP', 'flag': 'https://crests.football-data.org/760.svg'}, 'competition': {'id': 2014, 'name': 'Primera Division', 'code': 'PD', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/laliga.png'}, 'season': {'id': 2292, 'startDate': '2024-08-18', 'endDate': '2025-05-25', 'currentMatchday': 28, 'winner': None}, 'id': 498877, 'utcDate': '2025-03-27T00:00:00Z', 'status': 'SCHEDULED', 'matchday': 27, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2025-03-17T15:21:18Z', 'homeTeam': {'id': 81, 'name': 'FC Barcelona', 'shortName': 'Barça', 'tla': 'FCB', 'crest': 'https://crests.football-data.org/81.png'}, 'awayTeam': {'id': 79, 'name': 'CA Osasuna', 'shortName': 'Osasuna', 'tla': 'OSA', 'crest': 'https://crests.football-data.org/79.png'}, 'score': {'winner': 'DRAW', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 0}, 'halfTime': {'home': None, 'away': None}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 217698, 'name': 'Mateo Busquets Ferrer', 'type': 'REFEREE', 'nationality': 'Spain'}]}]}

# %%
# Now, the only thing we still need to do is concatenate the requests outputs together (equivalent of UNION ALL in SQL)

# First, let's get all the columns we will have in the final matches DataFrame
matches_columns = list(pd.DataFrame(matches_list[0]).columns)

# Creating an empty DataFrame
matches_df = pd.DataFrame(columns = matches_columns)

# Now, each element in matches_list is a list of dictionaries. We convert each element to a DataFrame, and concatenate it to the matches_df

for item in matches_list:
    matches_df = pd.concat([matches_df, pd.DataFrame(item)])

matches_df.reset_index(inplace=True, drop=True)

# And we finally have our matches source table, ready to be pushed to our raw DuckDB database
with duckdb.connect("C:/Users/mbmbm/matbx-data/sports-db-project/duckdb-databases/sports_db-raw.duckdb") as con:
    con.sql("CREATE OR REPLACE TABLE matches AS SELECT * FROM matches_df")

# %%
# Quick check
with duckdb.connect("C:/Users/mbmbm/matbx-data/sports-db-project/duckdb-databases/sports_db-raw.duckdb") as con:
    con.sql("SELECT * FROM matches").show()
# Out:
# ┌───────────────────────────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────────────────────────────────┬────────┬──────────────────────┬──────────┬──────────┬────────────────┬───────┬──────────────────────┬─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────────────────────────────────┐
# │                                             area                                              │                                                             competition                                                              │                                               season                                                │   id   │       utcDate        │  status  │ matchday │     stage      │ group │     lastUpdated      │                                                                homeTeam                                                                 │                                                               awayTeam                                                                │                                                         score                                                          │                              odds                              │                                            referees                                            │
# │                struct(id integer, "name" varchar, code varchar, flag varchar)                 │                           struct(id integer, "name" varchar, code varchar, "type" varchar, emblem varchar)                           │   struct(id integer, startdate varchar, enddate varchar, currentmatchday integer, winner integer)   │ int32  │       varchar        │ varchar  │  double  │    varchar     │ int32 │       varchar        │                            struct(id integer, "name" varchar, shortname varchar, tla varchar, crest varchar)                            │                           struct(id integer, "name" varchar, shortname varchar, tla varchar, crest varchar)                           │                                                        varchar                                                         │                      struct(msg varchar)                       │           struct(id integer, "name" varchar, "type" varchar, nationality varchar)[]            │
# ├───────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────┼────────┼──────────────────────┼──────────┼──────────┼────────────────┼───────┼──────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ {'id': 2032, 'name': Brazil, 'code': BRA, 'flag': https://crests.football-data.org/764.svg}   │ {'id': 2013, 'name': Campeonato Brasileiro Série A, 'code': BSA, 'type': LEAGUE, 'emblem': https://crests.football-data.org/bsa.png} │ {'id': 2257, 'startDate': 2024-04-13, 'endDate': 2024-12-08, 'currentMatchday': 38, 'winner': NULL} │ 493962 │ 2024-08-03T19:00:00Z │ FINISHED │     21.0 │ REGULAR_SEASON │  NULL │ 2024-12-22T20:20:40Z │ {'id': 1782, 'name': EC Vitória, 'shortName': Vitória, 'tla': VIT, 'crest': https://crests.football-data.org/1782.png}                  │ {'id': 4289, 'name': Cuiabá EC, 'shortName': Cuiabá EC, 'tla': CUI, 'crest': https://crests.football-data.org/4289_large.png}         │ {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 0}, 'halfTime': {'home': 0, 'away': 0}} │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ []                                                                                             │
# │ {'id': 2032, 'name': Brazil, 'code': BRA, 'flag': https://crests.football-data.org/764.svg}   │ {'id': 2013, 'name': Campeonato Brasileiro Série A, 'code': BSA, 'type': LEAGUE, 'emblem': https://crests.football-data.org/bsa.png} │ {'id': 2257, 'startDate': 2024-04-13, 'endDate': 2024-12-08, 'currentMatchday': 38, 'winner': NULL} │ 493961 │ 2024-08-03T22:00:00Z │ FINISHED │     21.0 │ REGULAR_SEASON │  NULL │ 2024-12-22T20:20:40Z │ {'id': 1780, 'name': CR Vasco da Gama, 'shortName': Vasco da Gama, 'tla': VAS, 'crest': https://crests.football-data.org/1780.png}      │ {'id': 4286, 'name': RB Bragantino, 'shortName': Bragantino, 'tla': RBB, 'crest': https://crests.football-data.org/4286.png}          │ {'winner': 'DRAW', 'duration': 'REGULAR', 'fullTime': {'home': 2, 'away': 2}, 'halfTime': {'home': 0, 'away': 1}}      │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ []                                                                                             │
# │ {'id': 2032, 'name': Brazil, 'code': BRA, 'flag': https://crests.football-data.org/764.svg}   │ {'id': 2013, 'name': Campeonato Brasileiro Série A, 'code': BSA, 'type': LEAGUE, 'emblem': https://crests.football-data.org/bsa.png} │ {'id': 2257, 'startDate': 2024-04-13, 'endDate': 2024-12-08, 'currentMatchday': 38, 'winner': NULL} │ 493954 │ 2024-08-03T23:00:00Z │ FINISHED │     21.0 │ REGULAR_SEASON │  NULL │ 2024-12-22T20:20:40Z │ {'id': 3988, 'name': AC Goianiense, 'shortName': AC Goianiense, 'tla': ACG, 'crest': https://crests.football-data.org/3988.png}         │ {'id': 1770, 'name': Botafogo FR, 'shortName': Botafogo, 'tla': BOT, 'crest': https://crests.football-data.org/1770.png}              │ {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 4}, 'halfTime': {'home': 1, 'away': 1}} │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ []                                                                                             │
# │ {'id': 2032, 'name': Brazil, 'code': BRA, 'flag': https://crests.football-data.org/764.svg}   │ {'id': 2013, 'name': Campeonato Brasileiro Série A, 'code': BSA, 'type': LEAGUE, 'emblem': https://crests.football-data.org/bsa.png} │ {'id': 2257, 'startDate': 2024-04-13, 'endDate': 2024-12-08, 'currentMatchday': 38, 'winner': NULL} │ 493956 │ 2024-08-03T23:00:00Z │ FINISHED │     21.0 │ REGULAR_SEASON │  NULL │ 2024-12-22T20:20:40Z │ {'id': 4243, 'name': Criciúma EC, 'shortName': Criciúma, 'tla': CRI, 'crest': https://crests.football-data.org/4243.png}                │ {'id': 1766, 'name': CA Mineiro, 'shortName': Mineiro, 'tla': CAM, 'crest': https://crests.football-data.org/1766.png}                │ {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 2, 'away': 1}, 'halfTime': {'home': 0, 'away': 0}} │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ []                                                                                             │
# │ {'id': 2032, 'name': Brazil, 'code': BRA, 'flag': https://crests.football-data.org/764.svg}   │ {'id': 2013, 'name': Campeonato Brasileiro Série A, 'code': BSA, 'type': LEAGUE, 'emblem': https://crests.football-data.org/bsa.png} │ {'id': 2257, 'startDate': 2024-04-13, 'endDate': 2024-12-08, 'currentMatchday': 38, 'winner': NULL} │ 493960 │ 2024-08-04T00:30:00Z │ FINISHED │     21.0 │ REGULAR_SEASON │  NULL │ 2024-12-22T20:20:40Z │ {'id': 1776, 'name': São Paulo FC, 'shortName': São Paulo, 'tla': PAU, 'crest': https://crests.football-data.org/1776.png}              │ {'id': 1783, 'name': CR Flamengo, 'shortName': Flamengo, 'tla': FLA, 'crest': https://crests.football-data.org/1783.png}              │ {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 0}, 'halfTime': {'home': 0, 'away': 0}} │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ []                                                                                             │
# │ {'id': 2032, 'name': Brazil, 'code': BRA, 'flag': https://crests.football-data.org/764.svg}   │ {'id': 2013, 'name': Campeonato Brasileiro Série A, 'code': BSA, 'type': LEAGUE, 'emblem': https://crests.football-data.org/bsa.png} │ {'id': 2257, 'startDate': 2024-04-13, 'endDate': 2024-12-08, 'currentMatchday': 38, 'winner': NULL} │ 493958 │ 2024-08-04T19:00:00Z │ FINISHED │     21.0 │ REGULAR_SEASON │  NULL │ 2024-12-22T20:20:40Z │ {'id': 1765, 'name': Fluminense FC, 'shortName': Fluminense, 'tla': FLU, 'crest': https://crests.football-data.org/1765.png}            │ {'id': 1777, 'name': EC Bahia, 'shortName': Bahia, 'tla': BAH, 'crest': https://crests.football-data.org/1777.png}                    │ {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 0}, 'halfTime': {'home': 1, 'away': 0}} │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ []                                                                                             │
# │ {'id': 2032, 'name': Brazil, 'code': BRA, 'flag': https://crests.football-data.org/764.svg}   │ {'id': 2013, 'name': Campeonato Brasileiro Série A, 'code': BSA, 'type': LEAGUE, 'emblem': https://crests.football-data.org/bsa.png} │ {'id': 2257, 'startDate': 2024-04-13, 'endDate': 2024-12-08, 'currentMatchday': 38, 'winner': NULL} │ 493955 │ 2024-08-04T19:00:00Z │ FINISHED │     21.0 │ REGULAR_SEASON │  NULL │ 2024-12-22T20:20:40Z │ {'id': 1779, 'name': SC Corinthians Paulista, 'shortName': Corinthians, 'tla': COR, 'crest': https://crests.football-data.org/1779.png} │ {'id': 4245, 'name': EC Juventude, 'shortName': Juventude, 'tla': JUV, 'crest': https://crests.football-data.org/4245_large.png}      │ {'winner': 'DRAW', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 1}, 'halfTime': {'home': 0, 'away': 1}}      │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ []                                                                                             │
# │ {'id': 2032, 'name': Brazil, 'code': BRA, 'flag': https://crests.football-data.org/764.svg}   │ {'id': 2013, 'name': Campeonato Brasileiro Série A, 'code': BSA, 'type': LEAGUE, 'emblem': https://crests.football-data.org/bsa.png} │ {'id': 2257, 'startDate': 2024-04-13, 'endDate': 2024-12-08, 'currentMatchday': 38, 'winner': NULL} │ 493953 │ 2024-08-04T19:00:00Z │ FINISHED │     21.0 │ REGULAR_SEASON │  NULL │ 2024-12-22T20:20:40Z │ {'id': 1768, 'name': CA Paranaense, 'shortName': Paranaense, 'tla': CAP, 'crest': https://crests.football-data.org/1768.png}            │ {'id': 1767, 'name': Grêmio FBPA, 'shortName': Grêmio, 'tla': FBP, 'crest': https://crests.football-data.org/1767.png}                │ {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 2}, 'halfTime': {'home': 0, 'away': 2}} │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ []                                                                                             │
# │ {'id': 2032, 'name': Brazil, 'code': BRA, 'flag': https://crests.football-data.org/764.svg}   │ {'id': 2013, 'name': Campeonato Brasileiro Série A, 'code': BSA, 'type': LEAGUE, 'emblem': https://crests.football-data.org/bsa.png} │ {'id': 2257, 'startDate': 2024-04-13, 'endDate': 2024-12-08, 'currentMatchday': 38, 'winner': NULL} │ 493959 │ 2024-08-04T20:00:00Z │ FINISHED │     21.0 │ REGULAR_SEASON │  NULL │ 2024-12-22T20:20:40Z │ {'id': 6684, 'name': SC Internacional, 'shortName': Internacional, 'tla': SCI, 'crest': https://crests.football-data.org/6684.png}      │ {'id': 1769, 'name': SE Palmeiras, 'shortName': Palmeiras, 'tla': PAL, 'crest': https://crests.football-data.org/1769.png}            │ {'winner': 'DRAW', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 1}, 'halfTime': {'home': 1, 'away': 0}}      │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ []                                                                                             │
# │ {'id': 2032, 'name': Brazil, 'code': BRA, 'flag': https://crests.football-data.org/764.svg}   │ {'id': 2013, 'name': Campeonato Brasileiro Série A, 'code': BSA, 'type': LEAGUE, 'emblem': https://crests.football-data.org/bsa.png} │ {'id': 2257, 'startDate': 2024-04-13, 'endDate': 2024-12-08, 'currentMatchday': 38, 'winner': NULL} │ 493957 │ 2024-08-06T00:00:00Z │ FINISHED │     21.0 │ REGULAR_SEASON │  NULL │ 2024-12-22T20:20:40Z │ {'id': 1771, 'name': Cruzeiro EC, 'shortName': Cruzeiro, 'tla': CRU, 'crest': https://crests.football-data.org/1771.png}                │ {'id': 3984, 'name': Fortaleza EC, 'shortName': Fortaleza, 'tla': FEC, 'crest': https://crests.football-data.org/3984.png}            │ {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 2}, 'halfTime': {'home': 1, 'away': 2}} │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ []                                                                                             │
# │                                             ·                                                 │                                                             ·                                                                        │                                                  ·                                                  │    ·   │          ·           │    ·     │       ·  │       ·        │    ·  │          ·           │                                                            ·                                                                            │                                                             ·                                                                         │                                                         ·                                                              │                               ·                                │ ·                                                                                              │
# │                                             ·                                                 │                                                             ·                                                                        │                                                  ·                                                  │    ·   │          ·           │    ·     │       ·  │       ·        │    ·  │          ·           │                                                            ·                                                                            │                                                             ·                                                                         │                                                         ·                                                              │                               ·                                │ ·                                                                                              │
# │                                             ·                                                 │                                                             ·                                                                        │                                                  ·                                                  │    ·   │          ·           │    ·     │       ·  │       ·        │    ·  │          ·           │                                                            ·                                                                            │                                                             ·                                                                         │                                                         ·                                                              │                               ·                                │ ·                                                                                              │
# │ {'id': 2224, 'name': Spain, 'code': ESP, 'flag': https://crests.football-data.org/760.svg}    │ {'id': 2014, 'name': Primera Division, 'code': PD, 'type': LEAGUE, 'emblem': https://crests.football-data.org/laliga.png}            │ {'id': 2292, 'startDate': 2024-08-18, 'endDate': 2025-05-25, 'currentMatchday': 28, 'winner': NULL} │ 498889 │ 2025-03-16T17:30:00Z │ FINISHED │     28.0 │ REGULAR_SEASON │  NULL │ 2025-03-19T00:21:19Z │ {'id': 87, 'name': Rayo Vallecano de Madrid, 'shortName': Rayo Vallecano, 'tla': RAY, 'crest': https://crests.football-data.org/87.png} │ {'id': 92, 'name': Real Sociedad de Fútbol, 'shortName': Real Sociedad, 'tla': RSO, 'crest': https://crests.football-data.org/92.png} │ {'winner': 'DRAW', 'duration': 'REGULAR', 'fullTime': {'home': 2, 'away': 2}, 'halfTime': {'home': 0, 'away': 1}}      │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ [{'id': 215569, 'name': Alejandro Muñiz Ruiz, 'type': REFEREE, 'nationality': Spain}]          │
# │ {'id': 2224, 'name': Spain, 'code': ESP, 'flag': https://crests.football-data.org/760.svg}    │ {'id': 2014, 'name': Primera Division, 'code': PD, 'type': LEAGUE, 'emblem': https://crests.football-data.org/laliga.png}            │ {'id': 2292, 'startDate': 2024-08-18, 'endDate': 2025-05-25, 'currentMatchday': 28, 'winner': NULL} │ 498884 │ 2025-03-16T17:30:00Z │ FINISHED │     28.0 │ REGULAR_SEASON │  NULL │ 2025-03-19T00:21:19Z │ {'id': 79, 'name': CA Osasuna, 'shortName': Osasuna, 'tla': OSA, 'crest': https://crests.football-data.org/79.png}                      │ {'id': 82, 'name': Getafe CF, 'shortName': Getafe, 'tla': GET, 'crest': https://crests.football-data.org/82.png}                      │ {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 2}, 'halfTime': {'home': 1, 'away': 0}} │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ [{'id': 206208, 'name': Alejandro Hernández Hernández, 'type': REFEREE, 'nationality': Spain}] │
# │ {'id': 2187, 'name': Portugal, 'code': POR, 'flag': https://crests.football-data.org/765.svg} │ {'id': 2017, 'name': Primeira Liga, 'code': PPL, 'type': LEAGUE, 'emblem': https://crests.football-data.org/PPL.png}                 │ {'id': 2312, 'startDate': 2024-08-11, 'endDate': 2025-05-17, 'currentMatchday': 26, 'winner': NULL} │ 503793 │ 2025-03-16T18:00:00Z │ FINISHED │     26.0 │ REGULAR_SEASON │  NULL │ 2025-03-19T00:21:19Z │ {'id': 496, 'name': Rio Ave FC, 'shortName': Rio Ave, 'tla': RIO, 'crest': https://crests.football-data.org/496.png}                    │ {'id': 1903, 'name': Sport Lisboa e Benfica, 'shortName': SL Benfica, 'tla': BEN, 'crest': https://crests.football-data.org/1903.png} │ {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 2, 'away': 3}, 'halfTime': {'home': 0, 'away': 1}} │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ []                                                                                             │
# │ {'id': 2088, 'name': Germany, 'code': DEU, 'flag': https://crests.football-data.org/759.svg}  │ {'id': 2002, 'name': Bundesliga, 'code': BL1, 'type': LEAGUE, 'emblem': https://crests.football-data.org/BL1.png}                    │ {'id': 2308, 'startDate': 2024-08-23, 'endDate': 2025-05-17, 'currentMatchday': 26, 'winner': NULL} │ 502596 │ 2025-03-16T18:30:00Z │ FINISHED │     26.0 │ REGULAR_SEASON │  NULL │ 2025-03-19T00:21:18Z │ {'id': 10, 'name': VfB Stuttgart, 'shortName': Stuttgart, 'tla': VFB, 'crest': https://crests.football-data.org/10.png}                 │ {'id': 3, 'name': Bayer 04 Leverkusen, 'shortName': Leverkusen, 'tla': B04, 'crest': https://crests.football-data.org/3.png}          │ {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 3, 'away': 4}, 'halfTime': {'home': 1, 'away': 0}} │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ [{'id': 15408, 'name': Daniel Siebert, 'type': REFEREE, 'nationality': Germany}]               │
# │ {'id': 2072, 'name': England, 'code': ENG, 'flag': https://crests.football-data.org/770.svg}  │ {'id': 2021, 'name': Premier League, 'code': PL, 'type': LEAGUE, 'emblem': https://crests.football-data.org/PL.png}                  │ {'id': 2287, 'startDate': 2024-08-16, 'endDate': 2025-05-25, 'currentMatchday': 29, 'winner': NULL} │ 497696 │ 2025-03-16T19:00:00Z │ FINISHED │     29.0 │ REGULAR_SEASON │  NULL │ 2025-03-19T00:21:19Z │ {'id': 338, 'name': Leicester City FC, 'shortName': Leicester City, 'tla': LEI, 'crest': https://crests.football-data.org/338.png}      │ {'id': 66, 'name': Manchester United FC, 'shortName': Man United, 'tla': MUN, 'crest': https://crests.football-data.org/66.png}       │ {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 3}, 'halfTime': {'home': 0, 'away': 1}} │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ [{'id': 11620, 'name': Thomas Bramall, 'type': REFEREE, 'nationality': England}]               │
# │ {'id': 2114, 'name': Italy, 'code': ITA, 'flag': https://crests.football-data.org/784.svg}    │ {'id': 2019, 'name': Serie A, 'code': SA, 'type': LEAGUE, 'emblem': https://crests.football-data.org/SA.png}                         │ {'id': 2310, 'startDate': 2024-08-18, 'endDate': 2025-05-25, 'currentMatchday': 29, 'winner': NULL} │ 503323 │ 2025-03-16T19:45:00Z │ FINISHED │     29.0 │ REGULAR_SEASON │  NULL │ 2025-03-19T00:21:19Z │ {'id': 102, 'name': Atalanta BC, 'shortName': Atalanta, 'tla': ATA, 'crest': https://crests.football-data.org/102.png}                  │ {'id': 108, 'name': FC Internazionale Milano, 'shortName': Inter, 'tla': INT, 'crest': https://crests.football-data.org/108.png}      │ {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 2}, 'halfTime': {'home': 0, 'away': 0}} │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ [{'id': 11029, 'name': Davide Massa, 'type': REFEREE, 'nationality': Italy}]                   │
# │ {'id': 2081, 'name': France, 'code': FRA, 'flag': https://crests.football-data.org/773.svg}   │ {'id': 2015, 'name': Ligue 1, 'code': FL1, 'type': LEAGUE, 'emblem': https://crests.football-data.org/FL1.png}                       │ {'id': 2290, 'startDate': 2024-08-18, 'endDate': 2025-05-18, 'currentMatchday': 26, 'winner': NULL} │ 498176 │ 2025-03-16T19:45:00Z │ FINISHED │     26.0 │ REGULAR_SEASON │  NULL │ 2025-03-19T00:21:19Z │ {'id': 524, 'name': Paris Saint-Germain FC, 'shortName': PSG, 'tla': PSG, 'crest': https://crests.football-data.org/524.png}            │ {'id': 516, 'name': Olympique de Marseille, 'shortName': Marseille, 'tla': MAR, 'crest': https://crests.football-data.org/516.png}    │ {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 3, 'away': 1}, 'halfTime': {'home': 2, 'away': 0}} │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ [{'id': 9374, 'name': Clément Turpin, 'type': REFEREE, 'nationality': France}]                 │
# │ {'id': 2224, 'name': Spain, 'code': ESP, 'flag': https://crests.football-data.org/760.svg}    │ {'id': 2014, 'name': Primera Division, 'code': PD, 'type': LEAGUE, 'emblem': https://crests.football-data.org/laliga.png}            │ {'id': 2292, 'startDate': 2024-08-18, 'endDate': 2025-05-25, 'currentMatchday': 28, 'winner': NULL} │ 498883 │ 2025-03-16T20:00:00Z │ FINISHED │     28.0 │ REGULAR_SEASON │  NULL │ 2025-03-19T00:21:19Z │ {'id': 78, 'name': Club Atlético de Madrid, 'shortName': Atleti, 'tla': ATL, 'crest': https://crests.football-data.org/78.png}          │ {'id': 81, 'name': FC Barcelona, 'shortName': Barça, 'tla': FCB, 'crest': https://crests.football-data.org/81.png}                    │ {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 2, 'away': 4}, 'halfTime': {'home': 1, 'away': 0}} │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ [{'id': 15628, 'name': Ricardo de Burgos, 'type': REFEREE, 'nationality': Spain}]              │
# │ {'id': 2187, 'name': Portugal, 'code': POR, 'flag': https://crests.football-data.org/765.svg} │ {'id': 2017, 'name': Primeira Liga, 'code': PPL, 'type': LEAGUE, 'emblem': https://crests.football-data.org/PPL.png}                 │ {'id': 2312, 'startDate': 2024-08-11, 'endDate': 2025-05-17, 'currentMatchday': 26, 'winner': NULL} │ 503796 │ 2025-03-16T20:30:00Z │ FINISHED │     26.0 │ REGULAR_SEASON │  NULL │ 2025-03-19T00:21:19Z │ {'id': 583, 'name': Moreirense FC, 'shortName': Moreirense, 'tla': MOR, 'crest': https://crests.football-data.org/583.png}              │ {'id': 810, 'name': Boavista FC, 'shortName': Boavista, 'tla': BOA, 'crest': https://crests.football-data.org/810.png}                │ {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 0}, 'halfTime': {'home': 1, 'away': 0}} │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ []                                                                                             │
# │ {'id': 2187, 'name': Portugal, 'code': POR, 'flag': https://crests.football-data.org/765.svg} │ {'id': 2017, 'name': Primeira Liga, 'code': PPL, 'type': LEAGUE, 'emblem': https://crests.football-data.org/PPL.png}                 │ {'id': 2312, 'startDate': 2024-08-11, 'endDate': 2025-05-17, 'currentMatchday': 26, 'winner': NULL} │ 503795 │ 2025-03-16T20:30:00Z │ FINISHED │     26.0 │ REGULAR_SEASON │  NULL │ 2025-03-19T00:21:19Z │ {'id': 5543, 'name': Vitória SC, 'shortName': Vitória SC, 'tla': GUI, 'crest': https://crests.football-data.org/5543.png}               │ {'id': 9136, 'name': CF Estrela da Amadora, 'shortName': Amadora, 'tla': AMA, 'crest': https://crests.football-data.org/9136.png}     │ {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 2, 'away': 0}, 'halfTime': {'home': 1, 'away': 0}} │ {'msg': Activate Odds-Package in User-Panel to retrieve odds.} │ []                                                                                             │
# ├───────────────────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────────────────────────────────┴────────┴──────────────────────┴──────────┴──────────┴────────────────┴───────┴──────────────────────┴─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2419 rows (20 shown)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               15 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# !jupyter nbconvert --to script football_data_pipeline.ipynb
# Out:
# [NbConvertApp] Converting notebook football_data_pipeline.ipynb to script
# [NbConvertApp] Writing 6699 bytes to football_data_pipeline.py
